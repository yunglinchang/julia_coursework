# %% [markdown]
# # 請設計Julia程式，1.進⾏新BMI指數的計算 2.輸入五項產品與金額

# %% [markdown]
# 第一題(如圖)補充：如果使用者輸入的不是數字，需要由系統判斷，並要求使用者重新輸入。
# 第二題：請使用者自行輸入五項產品的項目與金額，最後輸出結果要呈現消費總額及平均消費金額。
#
# 條件4:
# 希望最後結果呈現⽅方式如下: 王⼩小美您好!
# 您所輸入的資料如下: ⾝身⾼高:155公分 體重:52 公⽄斤
# 我們為您計算最新的BMI指數為:22.60
#
# ！注意！檔名格式請依照規定使用半型符號作為檔名不可有空白，如不同者視為未繳交哦～
# 檔名格式為：學號HW1
# ex:07170000HW1.jl
# (建議大家可以直接複製07170000HW1這個去改 .jl是檔案格式)

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202018-11-22%20%E4%B8%8B%E5%8D%883.10.16.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202018-11-22%20%E4%B8%8B%E5%8D%883.10.16.png)

# %% [markdown]
# 第一題

# %%
println("請輸入您的名字")
name = readline()

while true
    println("請輸入您的身高(公分)")
    global cmheight = readline()
    try
        parse(Float64, cmheight)
        break
    catch err
        if isa(err, ArgumentError) #出現ArgumentError
            #print("錯了")
        end
    end
end
cmheight = parse(Float64, cmheight)
mheight = cmheight/100

#println("請輸入您的體重(公斤)")
while true
    println("請輸入您的體重(公斤)")
    global weight = readline()
    try
        parse(Float64, weight)
        break
    catch err
        if isa(err, ArgumentError) #出現ArgumentError
            #print("錯了")
        end
    end
end
#weight = parse(Float64, readline())

newBMI = round((1.3*weight) / (mheight^2.5), digits=3)


println(name, "您好!")
println("您所輸入的資料如下: ","⾝高:", cmheight, " ","公分", " ", "體重:", weight, " ","公⽄")
println("我們為您計算最新的BMI指數為:", newBMI)
# Out:
# 請輸入您的名字
# stdin> 王小美
# 請輸入您的身高(公分)
# stdin> ㄊ
# 請輸入您的身高(公分)
# stdin> w
# 請輸入您的身高(公分)
# stdin> 155
# 請輸入您的體重(公斤)
# stdin> 52
# 王小美您好!
# 您所輸入的資料如下: ⾝高:155.0 公分 體重:52.0 公⽄
# 我們為您計算最新的BMI指數為:22.6

# %% [markdown]
# 第二題

# %%
println("請輸入第一項產品項目")
product1 = readline()
println("請輸入第一項產品金額")
price1 = parse(Float64, readline())

println("請輸入第二項產品項目")
product2 = readline()
println("請輸入第二項產品金額")
price2 = parse(Float64, readline())

println("請輸入第三項產品項目")
product3 = readline()
println("請輸入第三項產品金額")
price3 = parse(Float64, readline())

println("請輸入第四項產品項目")
product4 = readline()
println("請輸入第四項產品金額")
price4 = parse(Float64, readline())

println("請輸入第五項產品項目")
product5 = readline()
println("請輸入第五項產品金額")
price5 = parse(Float64, readline())

Total = price1 + price2 + price3 + price4 + price5
Average = Total/5

#消費總額及平均消費金額
println("消費總額: ", Total)
println("平均消費金額: ", Average)
# Out:
# 請輸入第一項產品項目
# stdin> 雞腿
# 請輸入第一項產品金額
# stdin> 1
# 請輸入第二項產品項目
# stdin> 鴨腿
# 請輸入第二項產品金額
# stdin> 1
# 請輸入第三項產品項目
# stdin> 羊腿
# 請輸入第三項產品金額
# stdin> 1
# 請輸入第四項產品項目
# stdin> 狗腿
# 請輸入第四項產品金額
# stdin> 1
# 請輸入第五項產品項目
# stdin> 豬腿
# 請輸入第五項產品金額
# stdin> 1
# 消費總額: 5.0
# 平均消費金額: 1.0
